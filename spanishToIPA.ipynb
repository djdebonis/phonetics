# %%
import re
import pandas as pd
import numpy as np

# %% [markdown]
# string = "rara"
# The idea here is to convert letters into (maybe phonemes and first)

# %%
string = "casado"

# %%
wordsThatWork = ["fiesta","quieto"]

# %%
# YOU HAVE TO FIGURE OUT HOW YOU'LL KEEP TRACK OF ALL THE POTENTIAL OPTIONS
transcriptions = []
transcription = ""
transcription1 = ""
transcription2 = ""
transcription3 = ""
for i in range(len(string)):
    
    # these letters are always constant consonants
    alwaysConsonantList = ['b','c','d','f','g','j','k','l','m','n','p','q','r','s','t','v','w','x','z']
    
    alwaysVowelList = ['a','e','i','o','u']
    
    postVocalicBreak = ['t','l']
    
    stringLength = len(string) # assign length of string to variable for easier comparrison
    
    # STRONG VOWELS: <a>, <e>, and <o>
    
    if string[i] == 'a':
        # all of the strong vowels, a|e|o, will automatically be concatenated; semivowells will be approached differently
        transcription = transcription + 'a'
        
        if (i < (stringLength-1)):
            # spanish vowels a, e, and o--when paired--are broken into separate syllables called a hiatus
            if string[i+1] == 'e' or string[i+1] == 'o':
                transcription = transcription + '-' 
                
            #elif string[i+1] in alwaysConsonantList:
             #   transcription = transcription + '-'

            # spanish vowels i and u--when paired with a, e, or o--become semivowels and make a diphthong
            elif string[i+1] == 'i':
                transcription = transcription+ 'i̯'
                i = i + 1
            elif string[i+1] == 'u':
                transcription = transcription + 'u̯'
                i = i +1
        print(transcription + ":" + str(i))
            
        
    elif string[i] == 'e':
        # all of the strong vowels, a|e|o, will automatically be concatenated; semivowells will be approached differently
        transcription = transcription + 'e'
        
        if (i < (stringLength-1)):
                    # spanish vowels a, e, and o--when paired--are broken into separate syllables called a hiatus
                    if string[i+1] == 'a' or string[i+1] == 'o':
                        transcription = transcription + '-' 
                   
                    #elif string[i+1] in alwaysConsonantList: YOU MUST BE MORE SPECIFIC HERE
                        #transcription = transcription + '-'

                    # spanish vowels i and u--when paired with a, e, or o--become semivowels and make a diphthong
                    elif string[i+1] == 'i':
                        transcription = transcription+ 'i̯'
                        i = i + 1
                    elif string[i+1] == 'u':
                        transcription = transcription + 'u̯'
                        i = i +1
                        
                    elif string[i+1] in postVocalicBreak:
                        transcription = transcription + '-'
        print(transcription + ":" + str(i))
                
         
    elif string[i] == 'o':
        # all of the strong vowels, a|e|o, will automatically be concatenated; semivowells will be approached differently
        transcription = transcription + 'o'

        if (i < (stringLength-1)):
            # spanish vowels a, e, and o--when paired--are broken into separate syllables called a hiatus
            if string[i+1] == 'e' or string[i+1] == 'a':
                transcription = transcription + '-' 
                
            elif string[i+1] in alwaysConsonantList:
                transcription = transcription + '-'

            # spanish vowels i and u--when paired with a, e, or o--become semivowels and make a diphthong
            elif string[i+1] == 'i':
                transcription = transcription+ 'i̯'
                i = i + 1
            elif string[i+1] == 'u':
                transcription = transcription + 'u̯'
                i = i +1
        print(transcription + ":" + str(i))

    
            
    # WEAK VOWELS: <i> and <u>
    
    # vowel <i>
    elif string[i] == 'i':
        if (i < (stringLength-1)):
            if string[i+1] == 'e' or string[i+1] == 'o' or string[i+1] == 'a':
                transcription = transcription + 'i̯'
                i = i + 1
                
        else:
            transcription = transcription + 'i'
            
            
        print(transcription + ":" + str(i))
        
    # vowel <u>
    elif string[i] == 'u':
        if (i < (stringLength-1)):
            if string[i+1] == 'e' or string[i+1] == 'o'or string[i+1] == 'a':
                transcription = transcription + 'u̯'
                i = i + 1
                
        else:
            transcription = transcription + 'u'
            
            
        print(transcription + ":" + str(i))
        
        
    # CONSONANTS:
    
    # consonant <f>
    elif string[i] == 'f':
        transcription = transcription + 'f'
          
        
    # consonant <s>  
    elif string[i] == 's':
        transcription = transcription + 's'
        if (i < stringLength-1):
            if string[i+1] in alwaysConsonantList: # spanish syllables are broken between <s> and other consonants
                    transcription = transcription + '-'
        
    elif string[i] == 'r':
        if i == 0:
            transcription = transcription + 'r'
            
            if (i < stringLength-1):
                if string[i+1] == 'r':
                    transcription = transcription + 'r'
            
                elif string[i-1] ==  'r':
                    transcription = transcription + ''
            
        
        else:
            transcription = transcription + 'ɾ'
            
       
        print(transcription + ":" + str(i))

    # consonant <t>
    elif string[i] == 't':
        transcription = transcription + 't'
        if (i < stringLength-1):
            if string[i+1] in alwaysConsonantList:
                transcription = transcription + 't'
       
        print(transcription + ":" + str(i))
        
    # consonant <q>
    elif string[i] == 'q':
        transcription = transcription + 'k'
        
        if(i < stringLength-1):
            if string[i+1] == 'u':
                i = i+1
                
    elif string[i] == 'h':
        if i == 0:
            if (i < stringLength-1):
                if string[i+1] == 'i':
                    if (i < stringLength-2):
                        if string[i + 2] == 'e' or string[i + 2] == 'a':
                            transcription = transcription + 'ʝ'
                            # YOU HAVE TO BE ABLE TO GIVE OTHER ANSWERS TOO
    
    elif string[i] == 'l':
        if (i < stringLength-1):
            if string[i+1] == 'l':
                transcription = transcription + 'ʝ|j|ʃ|ʒ|d͡ʒ|ʎ'
                i = i + 1
            else:
                transcription = transcription + 'l'
                
    elif string[i] == 'y':
        if (i < stringLength-1):
            if string[i+1] in alwaysVowelList:
                transcription = transcription + 'ʝ|j|ʃ|ʒ|d͡ʒ'
                
    elif string[i] == 'g':
        if i == 0:
            transcription = transcription + "g"
        elif string[i-1] == "n":
            transcription = transcription + "g"
        else:
            transcription = transcription + "ɣ"
            
    elif string[i] == 'n':
        if string[i+1] == "t" or string[i+1] == "d":
            transcription = transcription + "n̪"
            
        else:
            transcription = transcription + "n"
            
    elif string[i] == 'd':
        if i == 0:
            transcription = transcription + "d"
            
        elif string[i-1] == "n":
            transcription = transcription + "d"
        
        else:
            transcription = transcription + "ð"
            
        
    
        
### WRITE ANOTHER CODE THAT TAKES THE RESULT AND PARSES IT INTO INDIVIDUAL STRINGS OF THE DIFFERENT COMBOS

transcription
# Out:
# a:1
# asa:3
# asaðo:5
# 'asaðo'

# %%
for i in range(len(string)):
    if string[i] == 'a':
        
    elif string[i] =='b'
    
    elif string[i] =='c':
        if string[i+ 1] == 'h':
        
        elif string[i+1] == 'e|i':
        
        else:
    
    elif string[i] =='d'
        if i == 0:
            #i = 
    
    elif string[i] =='e':
        #i = e
    
    elif string[i] =='f':
    
    elif string[i] =='g':
        if i == 0:
            
    
    elif string[i] =='h'
    
    elif string[i] =='i'
    
    elif string[i] =='j'
    
    elif string[i] =='k'
    
    elif string[i] =='l'
    
    elif string[i] =='m'
    
    elif string[i] =='n'
    
    elif string[i] =='o'
    
    elif string[i] =='p'
    
    elif string[i] =='q'
    
    elif string[i] =='r':
        if string[i+1] == 'r':
            
            
    
    elif string[i] =='s'
    
    elif string[i] =='t'
    
    elif string[i] =='u'
    
    elif string[i] =='v'
    
    elif string[i] =='w'
    
    elif string[i] =='x'
    
    elif string[i] =='y'
    
    elif string[i] =='z'
    
    elif string[i] =='b'
    
    elif string[i] =='b'
# Out:
#   File "<ipython-input-93-27582233aefe>", line 4
#     elif string[i] =='b'
#        ^
# IndentationError: expected an indented block
